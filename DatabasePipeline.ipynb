# %%
import pandas as pd
import requests
from sqlalchemy import create_engine
from pipelineFunctions import json_flatten, json_structure
requests.packages.urllib3.disable_warnings()

# %%
#Protrak Portion
protrak_active_protocol_url = 'https://clinweb.cc.nih.gov/pqs/api/protocoldata/activeprotocols'
protrak_protocol_detail_url = 'https://clinweb.cc.nih.gov/pqs/api/protocoldata/bynum/'
data_fields = ['protocol_number', 'protocol_title', 'accrual_inst','accrual_status','coord_site','protrak_accrual_status','research_type','research_phase', 'study_type',
               'start_date_of_study', 'date_first_part_enrolled', 'irb_name', ]

# %%
session = requests.Session()
protocol_detail_session = requests.Session()
response = session.get(protrak_active_protocol_url, verify=False)

# %%
active_study_json = response.json()['protocols']
error_protocols = set()

# %%
detail_data = []
pi_data = []

#testing with first 10 protocols
for p in active_study_json:
    protocol_number = p['protocolNumber']


    #calling api for specific protocol details
    protocol_detail_response = protocol_detail_session.get(protrak_protocol_detail_url + protocol_number, verify=False)
    if protocol_detail_response.json()['responseCode'] != 200:
        error_protocols.add(protocol_number)
        continue
    detail_json = protocol_detail_response.json()['returnedProtocol']
    
    #flattened_detail_table = pd.json_normalize(json_flatten(detail_json))
    flattened_detail_json = json_flatten(detail_json)

    #getting pi information from API call
    investigators = detail_json['investigators']
    for i in investigators:
        if i['r'] == 'PI':
            pi_table = pi_data.append({'protocolNumber':protocol_number, 'firstName':i['n']['fn'], 'lastName':i['n']['ln'], 'middleName':i['n']['mn']})

    #detail_table = pd.concat([detail_table, flattened_detail_table])
    detail_data.append(flattened_detail_json)

pi_table = pd.json_normalize(pi_data)
detail_table = pd.json_normalize(detail_data)

# %%
protrak_table = detail_table[data_fields]

# %%
protrak_table
# Out:
#      protocol_number                                     protocol_title  \
# 0           002360-I  Single Use Expanded Access for 10E8.4/iMab and...
# 1          002357-AG  Deprescribing of Antipsychotic Medication amon...
# 2           002355-I  Olorofim Multiple Patient Access Program Singl...
# 3           002350-I  Single Use Compassionate Use for 10E8.4/iMab i...
# 4           002333-C  Expanded Use for Retreatment for a Single Pati...
# ...              ...                                                ...
# 1743      77-DK-0002      Natural History of Thyroid Function Disorders
# 1744      76-HG-0238  Diagnosis and Treatment of Patients with Inbor...
# 1745       76-H-0051  Lipoprotein Metabolism in Normal Volunteers an...
# 1746    OH76-DK-0256  Prospective Studies of Diabetes Mellitus and i...
# 1747      76-DK-0006  Natural History of Disorders of Insulin Resist...
#
#      accrual_inst                                accrual_status  coord_site  \
# 0           NIAID                             Special Exemption         NaN
# 1             NIA  No Longer Recruiting, subject follow-up only         NaN
# 2           NIAID                             Special Exemption         NaN
# 3           NIAID                             Special Exemption         NaN
# 4             NCI                             Special Exemption         NaN
# ...           ...                                           ...         ...
# 1743        NIDDK                                    Recruiting         NaN
# 1744        NHGRI                                    Recruiting         NaN
# 1745        NHLBI                        Open for Data Analysis         NaN
# 1746        NIDDK                        Open for Data Analysis         NaN
# 1747        NIDDK                                    Recruiting         NaN
#
#                          protrak_accrual_status research_type research_phase  \
# 0                             Special Exemption
# 1           No longer recruiting/follow-up only
# 2                             Special Exemption
# 3                             Special Exemption
# 4                             Special Exemption
# ...                                         ...           ...            ...
# 1743  Participants currently recruited/enrolled          R:NH            N/A
# 1744  Participants currently recruited/enrolled          R:NH            N/A
# 1745     Completed Study; data analyses ongoing          R:NH            N/A
# 1746     Completed Study; data analyses ongoing          R:NH            N/A
# 1747  Participants currently recruited/enrolled          R:NH            N/A
#
#            study_type start_date_of_study date_first_part_enrolled irb_name
# 0     Expanded Access          12/03/2024               12/03/2024  Panel 1
# 1       Observational          12/06/2024               12/06/2024  Panel 1
# 2     Expanded Access          12/02/2024               12/02/2024  Panel 1
# 3     Expanded Access          12/03/2024               12/03/2024  Panel 1
# 4     Expanded Access          10/30/2024               10/30/2024  Panel 1
# ...               ...                 ...                      ...      ...
# 1743    Observational          02/01/1977               02/01/1977  Panel 1
# 1744    Observational          09/12/1978               09/12/1978  Panel 1
# 1745    Observational          09/03/1976               09/03/1976  Panel 1
# 1746    Observational          09/03/1976               09/03/1976  Panel 1
# 1747    Observational          02/01/1976               02/01/1976  Panel 1
#
# [1748 rows x 12 columns]

# %%
#Pulling Protect API Data

main_api = 'https://protect-training.cc.nih.gov/TRAINING-IRB/sd/PublicCustomLayouts/PSLib/WebApi/multiResult?interfaceID=MultiIRBInformation'

session.auth = (u'crispi', '900DF7F9456F3B31A73C532C20986DEE45A0EC0A331CCBC519000E11DB4FBC0E')
session.verify = False
response = session.get(main_api)

# %%
study_id_list = set()
submission_list = []
all_submission_list = list()

for j in response.json():
    submission_list.append(j['ID'])
    study_id_list.add(j['parentStudyID'])
    all_submission_list.append(j)

# %%
basic_irb_API = "https://protect-training.cc.nih.gov/TRAINING-IRB/sd/PublicCustomLayouts/PSLib/WebApi/singleResult?interfaceID=BasicIRBInformation&resourceID="
multi_irb_api = "https://protect-training.cc.nih.gov/TRAINING-IRB/sd/PublicCustomLayouts/PSLib/WebApi/multiResult?interfaceID=MultiIRBInformation&$filter=parentProjectID eq "
add_submission_api = "https://protect-training.cc.nih.gov/TRAINING-IRB/sd/PublicCustomLayouts/PSLib/WebApi/singleResult?interfaceID=BasicIRBInformation&resourceID="

# %%
protect_data_fields = ['parentStudyID', 'piFirstName', 'piMiddleName', 'piLastName', 'piEmail', 'title', 'shortTitle', 'riskLevel', 'dateApproved', 'dateExpiration', 'studyTeamMembers',
                       'reportableNewInformation_category', 'reportableNewInformation_relatedStudies', 'reportableNewInformation_supportingDocuments', 'reportableNewInformation_rniDetermination']

# %%
protocols_done = list()

# %%
temp = list()

# %%
study_details_list = list()

for id in list(study_id_list)[:1]:
    study_detail_api = basic_irb_API + id

    response2 = session.get(study_detail_api)
    if response.status_code != 200:
        continue

    if 'data' in response2.json().keys():
        data = response2.json()['data']
    else:
        data = response2.json()


    #protocols_done.append(id)
    #study_details_list.append(data)
    temp.append(data)

# %%
len(study_details_list)
# Out:
# 4264

# %%
len(study_id_list)
# Out:
# 4264

# %%
protect_protocol_table = pd.json_normalize(study_details_list)[protect_data_fields]

# %%
#outer join on pi name, title, protocol number in order to find any discrepencies between the data sources
#protocolNumberAnti = protect_protocol_table.join(detail_table, how='outer', indicator=True, lsuffix='parentStudyID', rsuffix='protocolNumber')
protocolNumberAnti = pd.merge(protect_protocol_table, protrak_table, how='outer', indicator=True, left_on='parentStudyID', right_on='protocol_number')

# %%
protocolNumberAnti
# Out:
#      parentStudyID piFirstName piMiddleName    piLastName  \
# 0         15AA0031   Gene-Jack         None          Wang
# 1         19CH0026        Jack            A      Yanovski
# 2          01M0254      Carlos         None        Zarate
# 3        IRB002063      Lothar         None  Hennighausen
# 4        IRB002236    Krishnan         None         Patel
# ...            ...         ...          ...           ...
# 6007           NaN         NaN          NaN           NaN
# 6008           NaN         NaN          NaN           NaN
# 6009           NaN         NaN          NaN           NaN
# 6010           NaN         NaN          NaN           NaN
# 6011           NaN         NaN          NaN           NaN
#
#                      piEmail  \
# 0     gene-jack.wang@nih.gov
# 1      yanovskj@mail.nih.gov
# 2       zaratec@mail.nih.gov
# 3      lotharh@niddk.nih.gov
# 4     krishnan.patel@nih.gov
# ...                      ...
# 6007                     NaN
# 6008                     NaN
# 6009                     NaN
# 6010                     NaN
# 6011                     NaN
#
#                                                   title  \
# 0     Human Brain Mapping of the Apparent Diffusion ...
# 1     Randomized, Double-Blind, Placebo-Controlled S...
# 2     The Evaluation of Patients with Mood and Anxie...
# 3     Immune responses in COVID-19 patients and in v...
# 4     Understanding What Evidence Oncologists Consid...
# ...                                                 ...
# 6007                                                NaN
# 6008                                                NaN
# 6009                                                NaN
# 6010                                                NaN
# 6011                                                NaN
#
#                          shortTitle                     riskLevel  \
# 0          ADC changes during sleep  No greater than minimal risk
# 1              DCCR for Hyperphagia     Greater than minimal risk
# 2       Screening Protocol for MADP     Greater than minimal risk
# 3     NHSR - COVID vaccine response                           N/A
# 4          Oncology Practice Survey                           N/A
# ...                             ...                           ...
# 6007                            NaN                           NaN
# 6008                            NaN                           NaN
# 6009                            NaN                           NaN
# 6010                            NaN                           NaN
# 6011                            NaN                           NaN
#
#      dateApproved dateExpiration  ...          accrual_status coord_site  \
# 0      2024-09-03     2025-09-02  ...                     NaN        NaN
# 1      2024-05-07     2025-05-06  ...                     NaN        NaN
# 2      2024-09-25     2025-03-25  ...                     NaN        NaN
# 3      2024-03-04           None  ...                     NaN        NaN
# 4      2024-07-24           None  ...                     NaN        NaN
# ...           ...            ...  ...                     ...        ...
# 6007          NaN            NaN  ...              Recruiting        NaN
# 6008          NaN            NaN  ...              Recruiting        NaN
# 6009          NaN            NaN  ...  Open for Data Analysis        NaN
# 6010          NaN            NaN  ...  Open for Data Analysis        NaN
# 6011          NaN            NaN  ...              Recruiting        NaN
#
#                          protrak_accrual_status research_type research_phase  \
# 0                                           NaN           NaN            NaN
# 1                                           NaN           NaN            NaN
# 2                                           NaN           NaN            NaN
# 3                                           NaN           NaN            NaN
# 4                                           NaN           NaN            NaN
# ...                                         ...           ...            ...
# 6007  Participants currently recruited/enrolled          R:NH            N/A
# 6008  Participants currently recruited/enrolled          R:NH            N/A
# 6009     Completed Study; data analyses ongoing          R:NH            N/A
# 6010     Completed Study; data analyses ongoing          R:NH            N/A
# 6011  Participants currently recruited/enrolled          R:NH            N/A
#
#          study_type start_date_of_study date_first_part_enrolled irb_name  \
# 0               NaN                 NaN                      NaN      NaN
# 1               NaN                 NaN                      NaN      NaN
# 2               NaN                 NaN                      NaN      NaN
# 3               NaN                 NaN                      NaN      NaN
# 4               NaN                 NaN                      NaN      NaN
# ...             ...                 ...                      ...      ...
# 6007  Observational          02/01/1977               02/01/1977  Panel 1
# 6008  Observational          09/12/1978               09/12/1978  Panel 1
# 6009  Observational          09/03/1976               09/03/1976  Panel 1
# 6010  Observational          09/03/1976               09/03/1976  Panel 1
# 6011  Observational          02/01/1976               02/01/1976  Panel 1
#
#           _merge
# 0      left_only
# 1      left_only
# 2      left_only
# 3      left_only
# 4      left_only
# ...          ...
# 6007  right_only
# 6008  right_only
# 6009  right_only
# 6010  right_only
# 6011  right_only
#
# [6012 rows x 28 columns]
