# %%
import re
import pandas as pd
import requests
from sqlalchemy import create_engine
import psycopg2
from pipelineFunctions import json_flatten, json_structure
requests.packages.urllib3.disable_warnings()

# %%
active_protocol_url = 'https://clinweb.cc.nih.gov/pqs/api/protocoldata/activeprotocols'
protocol_detail_url = 'https://clinweb.cc.nih.gov/pqs/api/protocoldata/bynum/'

# %%
session = requests.Session()
protocol_detail_session = requests.Session()
response = session.get(active_protocol_url, verify=False)

# %%
data_fields = ['protocol_number', 'simpleProtocolNumber', 'protocol_title', 'accrual_inst','accrual_status','coord_site','protrak_accrual_status','research_type','research_phase', 'study_type',
               'start_date_of_study', 'date_first_part_enrolled', 'irb_name', 'z_number', 'nct_number', 'currentEnrollment','plannedEnrollment']

# %%
active_study_json = response.json()['protocols']

# %%
detail_data = []
pi_data = []

for p in active_study_json:
    protocol_number = p['protocolNumber']
    simplified_protocol_number = ''.join(re.findall('[0-9]+', p['protocolNumber']))


    #calling api for specific protocol details
    protocol_detail_response = protocol_detail_session.get(protocol_detail_url + protocol_number, verify=False)
    if protocol_detail_response.json()['responseCode'] != 200:
        continue
    
    detail_json = protocol_detail_response.json()['returnedProtocol']
    
    #flattened_detail_table = pd.json_normalize(json_flatten(detail_json))
    flattened_detail_json = json_flatten(detail_json)
    flattened_detail_json['simpleProtocolNumber'] = simplified_protocol_number

    #getting pi information from API call
    investigators = detail_json['investigators']
    for i in investigators:
        if i['r'] == 'PI':
            pi_table = pi_data.append({'protocolNumber':protocol_number, 'firstName':i['n']['fn'], 'lastName':i['n']['ln'], 'middleName':i['n']['mn'], 'piName':'{0} {1} {2}'.format(i['n']['fn'],i['n']['ln'],i['n']['mn'])})

    enrollmentForms = detail_json.get('enrollment_forms','')
    if enrollmentForms:
        enrollmentForms = enrollmentForms[0]
        currentEnrollment = enrollmentForms['total_american_indian'] + enrollmentForms['total_asian'] + enrollmentForms['total_black'] + enrollmentForms['total_hawaiian'] + enrollmentForms['total_more_than_one_race'] + enrollmentForms['total_unknowns'] + enrollmentForms['total_white']
    else:
        currentEnrollment = ''

    targetEnrollments = detail_json.get('target_enrollments','')
    if targetEnrollments:
        targetEnrollments = targetEnrollments[0]
        targetEnrollment = targetEnrollments['total_american_indian'] + targetEnrollments['total_asian'] + targetEnrollments['total_black'] + targetEnrollments['total_hawaiian'] + targetEnrollments['total_more_than_one_race'] + targetEnrollments['total_white']
    else:
        targetEnrollment = ''

    flattened_detail_json['currentEnrollment'] = currentEnrollment
    flattened_detail_json['plannedEnrollment'] = targetEnrollment

    #detail_table = pd.concat([detail_table, flattened_detail_table])
    detail_data.append(flattened_detail_json)

pi_table = pd.json_normalize(pi_data)
detail_table = pd.json_normalize(detail_data)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 6
#       4 for p in active_study_json:
#       5     protocol_number = p['protocolNumber']
# ----> 6     simplified_protocol_number = re.search('[0-9]{6}', p['protocolNumber']).group()
#       9     #calling api for specific protocol details
#      10     protocol_detail_response = protocol_detail_session.get(protocol_detail_url + protocol_number, verify=False)
#
# AttributeError: 'NoneType' object has no attribute 'group'

# %%
final_table = detail_table[data_fields]

# %%
final_table.join(pi_table, lsuffix='protocol_number', rsuffix='protocolNumber')
# Out:
#      protocol_number                            simpleProtocolNumber  \
# 0           002373-C  <re.Match object; span=(0, 6), match='002373'>
# 1           002360-I  <re.Match object; span=(0, 6), match='002360'>
# 2          002357-AG  <re.Match object; span=(0, 6), match='002357'>
# 3           002355-I  <re.Match object; span=(0, 6), match='002355'>
# 4           002350-I  <re.Match object; span=(0, 6), match='002350'>
# ...              ...                                             ...
# 1746      77-DK-0002                                            None
# 1747      76-HG-0238                                            None
# 1748       76-H-0051                                            None
# 1749    OH76-DK-0256                                            None
# 1750      76-DK-0006                                            None
#
#                                          protocol_title accrual_inst  \
# 0     Single Patient Protocol: Administration of PDS...          NCI
# 1     Single Use Expanded Access for 10E8.4/iMab and...        NIAID
# 2     Deprescribing of Antipsychotic Medication amon...          NIA
# 3     Olorofim Multiple Patient Access Program Singl...        NIAID
# 4     Single Use Compassionate Use for 10E8.4/iMab i...        NIAID
# ...                                                 ...          ...
# 1746      Natural History of Thyroid Function Disorders        NIDDK
# 1747  Diagnosis and Treatment of Patients with Inbor...        NHGRI
# 1748  Lipoprotein Metabolism in Normal Volunteers an...        NHLBI
# 1749  Prospective Studies of Diabetes Mellitus and i...        NIDDK
# 1750  Natural History of Disorders of Insulin Resist...        NIDDK
#
#                                     accrual_status  coord_site  \
# 0                                Special Exemption         NaN
# 1                                Special Exemption         NaN
# 2     No Longer Recruiting, subject follow-up only         NaN
# 3                                Special Exemption         NaN
# 4                                Special Exemption         NaN
# ...                                            ...         ...
# 1746                                    Recruiting         NaN
# 1747                                    Recruiting         NaN
# 1748                        Open for Data Analysis         NaN
# 1749                        Open for Data Analysis         NaN
# 1750                                    Recruiting         NaN
#
#                          protrak_accrual_status research_type research_phase  \
# 0                             Special Exemption
# 1                             Special Exemption
# 2           No longer recruiting/follow-up only
# 3                             Special Exemption
# 4                             Special Exemption
# ...                                         ...           ...            ...
# 1746  Participants currently recruited/enrolled          R:NH            N/A
# 1747  Participants currently recruited/enrolled          R:NH            N/A
# 1748     Completed Study; data analyses ongoing          R:NH            N/A
# 1749     Completed Study; data analyses ongoing          R:NH            N/A
# 1750  Participants currently recruited/enrolled          R:NH            N/A
#
#            study_type  ... irb_name     z_number   nct_number  \
# 0     Expanded Access  ...  Panel 1         None         None
# 1     Expanded Access  ...  Panel 1         None         None
# 2       Observational  ...  Panel 1         None         None
# 3     Expanded Access  ...  Panel 1         None         None
# 4     Expanded Access  ...  Panel 1         None         None
# ...               ...  ...      ...          ...          ...
# 1746    Observational  ...  Panel 1  ZIADK047053  NCT00001159
# 1747    Observational  ...  Panel 1  ZIAHG000215  NCT00369421
# 1748    Observational  ...  Panel 1  ZIAHL006199  NCT00001154
# 1749    Observational  ...  Panel 1  ZIADK069028  NCT00339482
# 1750    Observational  ...  Panel 1  ZIADK047050  NCT00001987
#
#      currentEnrollment plannedEnrollment protocolNumber firstName   lastName  \
# 0                                              002373-C  Danielle     Pastor
# 1                                              002360-I   Michael    Sneller
# 2                                             002357-AG       Mir        Ali
# 3                                              002355-I    Steven    Holland
# 4                                              002350-I   Michael    Sneller
# ...                ...               ...            ...       ...        ...
# 1746               950                       77-DK-0002    Sriram      Gubbi
# 1747              3616                       76-HG-0238   William       Gahl
# 1748               759                        76-H-0051    Robert  Shamburek
# 1749             12647                     OH76-DK-0256    Robert     Hanson
# 1750               683              1200     76-DK-0006   Rebecca      Brown
#
#      middleName              piName
# 0             M   Danielle Pastor M
# 1             C   Michael Sneller C
# 2             M           Mir Ali M
# 3             M    Steven Holland M
# 4             C   Michael Sneller C
# ...         ...                 ...
# 1746          M      Sriram Gubbi M
# 1747          A      William Gahl A
# 1748          D  Robert Shamburek D
# 1749          L     Robert Hanson L
# 1750          J     Rebecca Brown J
#
# [1751 rows x 22 columns]

# %%
db = create_engine('postgresql://chiangpt:listle99@10.157.90.23:5432/Dashboard')
conn = db.connect()
final_table.to_sql('Protrak_Data_Table', con=conn, if_exists='replace', index='false')
pi_table.to_sql('Protrak_PI_Table', con=conn, if_exists='replace', index='false')
# Out:
# 749

# %%
final_table
# Out:
#      protocol_number                                     protocol_title  \
# 0           002360-I  Single Use Expanded Access for 10E8.4/iMab and...
# 1          002357-AG  Deprescribing of Antipsychotic Medication amon...
# 2           002355-I  Olorofim Multiple Patient Access Program Singl...
# 3           002350-I  Single Use Compassionate Use for 10E8.4/iMab i...
# 4           002333-C  Expanded Use for Retreatment for a Single Pati...
# ...              ...                                                ...
# 1744      77-DK-0002      Natural History of Thyroid Function Disorders
# 1745      76-HG-0238  Diagnosis and Treatment of Patients with Inbor...
# 1746       76-H-0051  Lipoprotein Metabolism in Normal Volunteers an...
# 1747    OH76-DK-0256  Prospective Studies of Diabetes Mellitus and i...
# 1748      76-DK-0006  Natural History of Disorders of Insulin Resist...
#
#      accrual_inst                                accrual_status  coord_site  \
# 0           NIAID                             Special Exemption         NaN
# 1             NIA  No Longer Recruiting, subject follow-up only         NaN
# 2           NIAID                             Special Exemption         NaN
# 3           NIAID                             Special Exemption         NaN
# 4             NCI                             Special Exemption         NaN
# ...           ...                                           ...         ...
# 1744        NIDDK                                    Recruiting         NaN
# 1745        NHGRI                                    Recruiting         NaN
# 1746        NHLBI                        Open for Data Analysis         NaN
# 1747        NIDDK                        Open for Data Analysis         NaN
# 1748        NIDDK                                    Recruiting         NaN
#
#                          protrak_accrual_status research_type research_phase  \
# 0                             Special Exemption
# 1           No longer recruiting/follow-up only
# 2                             Special Exemption
# 3                             Special Exemption
# 4                             Special Exemption
# ...                                         ...           ...            ...
# 1744  Participants currently recruited/enrolled          R:NH            N/A
# 1745  Participants currently recruited/enrolled          R:NH            N/A
# 1746     Completed Study; data analyses ongoing          R:NH            N/A
# 1747     Completed Study; data analyses ongoing          R:NH            N/A
# 1748  Participants currently recruited/enrolled          R:NH            N/A
#
#            study_type start_date_of_study date_first_part_enrolled irb_name  \
# 0     Expanded Access          12/03/2024               12/03/2024  Panel 1
# 1       Observational          12/06/2024               12/06/2024  Panel 1
# 2     Expanded Access          12/02/2024               12/02/2024  Panel 1
# 3     Expanded Access          12/03/2024               12/03/2024  Panel 1
# 4     Expanded Access          10/30/2024               10/30/2024  Panel 1
# ...               ...                 ...                      ...      ...
# 1744    Observational          02/01/1977               02/01/1977  Panel 1
# 1745    Observational          09/12/1978               09/12/1978  Panel 1
# 1746    Observational          09/03/1976               09/03/1976  Panel 1
# 1747    Observational          09/03/1976               09/03/1976  Panel 1
# 1748    Observational          02/01/1976               02/01/1976  Panel 1
#
#          z_number   nct_number currentEnrollment plannedEnrollment
# 0            None         None
# 1            None         None
# 2            None         None
# 3            None         None
# 4            None         None
# ...           ...          ...               ...               ...
# 1744  ZIADK047053  NCT00001159               950
# 1745  ZIAHG000215  NCT00369421              3616
# 1746  ZIAHL006199  NCT00001154               759
# 1747  ZIADK069028  NCT00339482             12647
# 1748  ZIADK047050  NCT00001987               683              1200
#
# [1749 rows x 16 columns]

# %%
pi_table
# Out:
#      protocolNumber firstName   lastName middleName              piName
# 0          002360-I   Michael    Sneller          C   Michael Sneller C
# 1         002357-AG       Mir        Ali          M           Mir Ali M
# 2          002355-I    Steven    Holland          M    Steven Holland M
# 3          002350-I   Michael    Sneller          C   Michael Sneller C
# 4          002333-C    Steven  Rosenberg          A  Steven Rosenberg A
# ...             ...       ...        ...        ...                 ...
# 1744     77-DK-0002    Sriram      Gubbi          M      Sriram Gubbi M
# 1745     76-HG-0238   William       Gahl          A      William Gahl A
# 1746      76-H-0051    Robert  Shamburek          D  Robert Shamburek D
# 1747   OH76-DK-0256    Robert     Hanson          L     Robert Hanson L
# 1748     76-DK-0006   Rebecca      Brown          J     Rebecca Brown J
#
# [1749 rows x 5 columns]
